# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

Complete_data= pd.merge(mouse_metadata, study_results, on = 'Mouse ID')
Complete_data.sample(10)
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 701      c757      Placebo    Male           9          27         20
# 491      a275     Ceftamin  Female          20          28         35
# 627      b879     Stelasyn  Female           4          26         45
# 1702     w422     Ketapril  Female          18          26         40
# 1216     n482     Propriva  Female           4          29          0
# 1049     k483    Infubinol  Female          20          30         25
# 282      l897    Capomulin    Male          17          19         45
# 1144     l725     Naftisol  Female           8          26          5
# 902      g570     Propriva    Male          16          29         40
# 1305     o809    Infubinol    Male           3          25          0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 701            52.818634                 1
# 491            56.353538                 2
# 627            72.555239                 2
# 1702           63.072585                 4
# 1216           45.000000                 0
# 1049           57.432007                 2
# 282            38.846876                 1
# 1144           48.736319                 1
# 902            68.525856                 2
# 1305           45.000000                 0

# %%
num_mice = Complete_data['Mouse ID'].nunique()
num_mice
# Out:
# 249

# %%
mice_id =
